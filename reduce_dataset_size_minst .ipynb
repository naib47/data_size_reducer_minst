# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (2.12.0rc1)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (2.12.0rc1)
# Requirement already satisfied: tensorflow-intel==2.12.0-rc1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.12.0rc1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.5)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (15.0.6.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (4.22.1)
# Requirement already satisfied: setuptools in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.51.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0rc0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0rc0)
# Requirement already satisfied: keras<2.13,>=2.12.0rc0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0rc1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0-rc1->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0-rc1->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.2.2)

# %%
import keras
import random
import collections

import numpy as np

# %%
 pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (2.12.0rc1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow-intel==2.12.0-rc1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.12.0rc1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.5)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (15.0.6.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (4.22.1)
# Requirement already satisfied: setuptools in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (1.51.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0rc0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0rc0)
# Requirement already satisfied: keras<2.13,>=2.12.0rc0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (2.12.0rc1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0-rc1->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0-rc1->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0-rc1->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\infon\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0-rc1->tensorflow) (3.2.2)

# %%
def display_random_images_with_labels(d, n=10):
    """
        accept dataset in tuple form, first index
        is np arrays (images) and second is labels
        and display n random images with labels
        from it
        Inputs:
            d (tuple): dataset images, dataset labels on same indexs
            n (int): number of samples to display (default: 10)
        Output:
            None
    """
    choices = list(range(len(d[0])))
    for i in range(n):
        index = random.choice(choices)
        choices.remove(index)
        print("index:",index)
        print("Lable:",d[1][index])
        plt.imshow(d[0][index], cmap='gray')
        plt.show()

import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
import tensorflow.keras as tk

# %%
# Loading dataset
dataset = keras.datasets.mnist.load_data()

# Description of dataset

# mnint is handwritten digits (0 to 9) images dataset
# keras.datasets.mnist.load_data() loads those images in gray scale as cv2 images / np arrays
# with those labels


# dataset is in tuple form,
# its first index dataset[0] represents training dataset
# its second index dataset[1] represents testing dataset

# Both training (dataset[0]) and testing (dataset[1]) datasets
# are further tuples and have two elements,

# first element of both training and testing (dataset[0][0] and dataset[0][0])
# represnts images in numpy arrays
print("There are",len(dataset[0][0]),"images in training dataset")
print("There are",len(dataset[1][0]),"images in training dataset")
print("___________________\n\n")
# Each image is of shape 28x28
# print(dataset[0][0][0].shape)
# print("___________________")


# second element of both training and testing (dataset[0][1] and dataset[0][1])
# represnts labels of the images, presents on the same index in images
# For example dataset[0][0][0] is an image in training dataset
# and dataset[0][1][0] is the label of same image is training dataset
print("Randomly printing 10 images with labels from training dataset")
display_random_images_with_labels(dataset[0])
print("___________________\n\n")
print("Randomly printing 10 images with labels from testing dataset")
display_random_images_with_labels(dataset[0])
print("___________________\n\n")

print("There are",len(dataset[0][1]),"labels in training dataset for",len(dataset[0][0]),"images in training dataset")
print("There are",len(dataset[1][1]),"labels in training dataset for",len(dataset[1][0]),"images in training dataset")
print("___________________\n\n")

print("There are", len(set(dataset[0][1])),"unique classes in training dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(dataset[0][1]))
print("There are", len(set(dataset[1][1])),"unique classes in validation dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(dataset[1][1]))
print("___________________\n\n")
# Out:
# There are 60000 images in training dataset
# There are 10000 images in training dataset
# ___________________
#
#
# Randomly printing 10 images with labels from training dataset
# index: 14532
# Lable: 7
# index: 56095
# Lable: 7
# index: 38722
# Lable: 0
# index: 41025
# Lable: 5
# index: 7318
# Lable: 0
# index: 11337
# Lable: 1
# index: 42220
# Lable: 3
# index: 3122
# Lable: 1
# index: 45301
# Lable: 9
# index: 11093
# Lable: 1
# ___________________
#
#
# Randomly printing 10 images with labels from testing dataset
# index: 113
# Lable: 1
# index: 12689
# Lable: 5
# index: 6993
# Lable: 9
# index: 17210
# Lable: 0
# index: 19985
# Lable: 0
# index: 52177
# Lable: 1
# index: 22318
# Lable: 3
# index: 41056
# Lable: 0
# index: 47123
# Lable: 3
# index: 5100
# Lable: 7
# ___________________
#
#
# There are 60000 labels in training dataset for 60000 images in training dataset
# There are 10000 labels in training dataset for 10000 images in training dataset
# ___________________
#
#
# There are 10 unique classes in training dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({5: 5421,
#          0: 5923,
#          4: 5842,
#          1: 6742,
#          9: 5949,
#          2: 5958,
#          3: 6131,
#          6: 5918,
#          7: 6265,
#          8: 5851})
# There are 10 unique classes in validation dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({7: 1028,
#          2: 1032,
#          1: 1135,
#          0: 980,
#          4: 982,
#          9: 1009,
#          5: 892,
#          6: 958,
#          3: 1010,
#          8: 974})
# ___________________

# %% [markdown]
# # Task
#
# You have to reduce the size of this dataset by 10 times.
#
# There are currently almost 5000 to 6000 thousand images (total: 60000) for each label in training and almost 1000 images (total: 10000) for each label in testing dataset.
#
# You are required to reduce this training dataset so that it will have exactly 600 images for each label (total: 6000) in training dataset and exactly 100 images for each label in testing dataset (total: 1000)
#
# new dataset should be stored into new_dataset variable name and should have exactly same format as the original dataset.

# %%
# Your code here
(train_data, train_labels), (test_data, test_labels) = dataset

print("Training data shape: ", train_data.shape) 
print("Training labels shape: ", train_labels.shape) 
print("Test data shape: ", test_data.shape) 
print("Test labels shape: ", test_labels.shape)
# Out:
# Training data shape:  (60000, 28, 28)
# Training labels shape:  (60000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)

# %%
print("Randomly printing 10 images with labels from training dataset")
display_random_images_with_labels(dataset[0])
print("___________________\n\n")
# Out:
# Randomly printing 10 images with labels from training dataset
# index: 22169
# Lable: 2
# index: 11447
# Lable: 4
# index: 22318
# Lable: 3
# index: 42267
# Lable: 5
# index: 8868
# Lable: 6
# index: 34035
# Lable: 4
# index: 35270
# Lable: 1
# index: 41224
# Lable: 7
# index: 46562
# Lable: 0
# index: 20815
# Lable: 5
# ___________________

# %%
print("There are",len(dataset[0][1]),"labels in training dataset for",len(dataset[0][0]),"images in training dataset")
# Out:
# There are 60000 labels in training dataset for 60000 images in training dataset

# %%
print("There are",len(dataset[1][1]),"labels in testing dataset for",len(dataset[1][0]),"images in testing dataset")
# Out:
# There are 10000 labels in testing dataset for 10000 images in testing dataset

# %%
print("There are", len(set(dataset[0][1])),"unique classes in training dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(dataset[0][1]))
print("There are", len(set(dataset[1][1])),"unique classes in validation dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(dataset[1][1]))
print("___________________\n\n")
# Out:
# There are 10 unique classes in training dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({5: 5421,
#          0: 5923,
#          4: 5842,
#          1: 6742,
#          9: 5949,
#          2: 5958,
#          3: 6131,
#          6: 5918,
#          7: 6265,
#          8: 5851})
# There are 10 unique classes in validation dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({7: 1028,
#          2: 1032,
#          1: 1135,
#          0: 980,
#          4: 982,
#          9: 1009,
#          5: 892,
#          6: 958,
#          3: 1010,
#          8: 974})
# ___________________

# %%
print("There are",len(dataset[0][1]),"labels in training dataset for",len(dataset[0][0]),"images in training dataset")
print("There are",len(dataset[1][1]),"labels in training dataset for",len(dataset[1][0]),"images in training dataset")
print("___________________\n\n")
# Out:
# There are 60000 labels in training dataset for 60000 images in training dataset
# There are 10000 labels in training dataset for 10000 images in training dataset
# ___________________

# %%
(train_data, train_labels), (test_data, test_labels) = dataset

label_images = {}
for i in range(len(train_data)):
    label = train_labels[i]
    if label not in label_images:
        label_images[label] = []
    label_images[label].append(i)
    
new_training_indices = []
for label, images in label_images.items():
    if len(images) > 600:
        images = random.sample(images, 600)
    new_training_indices.extend(images)
    
new_train_data = train_data[new_training_indices]
new_train_labels = train_labels[new_training_indices]

label_images = {}
for i in range(len(test_data)):
    label = test_labels[i]
    if label not in label_images:
        label_images[label] = []
    label_images[label].append(i)
    
new_test_indices = []
for label, images in label_images.items():
    if len(images) > 100:
        images = random.sample(images, 100)
    new_test_indices.extend(images)
    
new_test_data = test_data[new_test_indices]
new_test_labels = test_labels[new_test_indices]

new_dataset = ((new_train_data, new_train_labels), (new_test_data, new_test_labels))

print("There are", len(set(new_train_labels)), "unique classes in the reduced training dataset.")
print("Breakdown of each label is below (format: dict key is label, dict value is occurrence of that label/number of images for that label)")
print(dict(sorted(collections.Counter(new_train_labels).items())))

print("There are", len(set(new_test_labels)), "unique classes in the reduced test dataset.")
print("Breakdown of each label is below (format: dict key is label, dict value is occurrence of that label/number of images for that label)")
print(dict(sorted(collections.Counter(new_test_labels).items())))
# Out:
# There are 10 unique classes in the reduced training dataset.
# Breakdown of each label is below (format: dict key is label, dict value is occurrence of that label/number of images for that label)
# {0: 600, 1: 600, 2: 600, 3: 600, 4: 600, 5: 600, 6: 600, 7: 600, 8: 600, 9: 600}
# There are 10 unique classes in the reduced test dataset.
# Breakdown of each label is below (format: dict key is label, dict value is occurrence of that label/number of images for that label)
# {0: 100, 1: 100, 2: 100, 3: 100, 4: 100, 5: 100, 6: 100, 7: 100, 8: 100, 9: 100}

# %%
print(new_dataset[0][0][0].shape)
print("___________________")
# Out:
# (28, 28)
# ___________________

# %%
#Checking the size of dataset
print("There are",len(new_dataset[0][1]),"labels in training dataset for",len(new_dataset[0][0]),"images in training dataset")
print("There are",len(new_dataset[1][1]),"labels in training dataset for",len(new_dataset[1][0]),"images in training dataset")
print("___________________\n\n")
# Excepted output
# There are 6000 labels in training dataset for 6000 images in training dataset
# There are 1000 labels in training dataset for 1000 images in training dataset
# Out:
# There are 6000 labels in training dataset for 6000 images in training dataset
# There are 1000 labels in training dataset for 1000 images in training dataset
# ___________________

# %%
#Checking the number of images per class
print("There are", len(set(new_dataset[0][1])),"unique classes in training dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(new_dataset[0][1]))
print("There are", len(set(new_dataset[1][1])),"unique classes in validation dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(new_dataset[1][1]))
print("___________________\n\n")
# Out:
# There are 10 unique classes in training dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({5: 600,
#          0: 600,
#          4: 600,
#          1: 600,
#          9: 600,
#          2: 600,
#          3: 600,
#          6: 600,
#          7: 600,
#          8: 600})
# There are 10 unique classes in validation dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({7: 100,
#          2: 100,
#          1: 100,
#          0: 100,
#          4: 100,
#          9: 100,
#          5: 100,
#          6: 100,
#          3: 100,
#          8: 100})
# ___________________

# %%
# Checking the correctness of indexing of image and its labels
print("Randomly printing 10 images with labels from training dataset")
display_random_images_with_labels(new_dataset[0])
print("___________________\n\n")
# Out:
# Randomly printing 10 images with labels from training dataset
# index: 2100
# Lable: 1
# index: 5814
# Lable: 8
# index: 5882
# Lable: 8
# index: 4899
# Lable: 7
# index: 2259
# Lable: 1
# index: 1393
# Lable: 4
# index: 2572
# Lable: 9
# index: 2835
# Lable: 9
# index: 5101
# Lable: 7
# index: 3963
# Lable: 3
# ___________________

# %%
print("Randomly printing 10 images with labels from testing dataset")
display_random_images_with_labels(new_dataset[0])
print("___________________\n\n")
# Out:
# Randomly printing 10 images with labels from testing dataset
# index: 3098
# Lable: 2
# index: 5135
# Lable: 7
# index: 4944
# Lable: 7
# index: 950
# Lable: 0
# index: 4382
# Lable: 6
# index: 2310
# Lable: 1
# index: 1926
# Lable: 1
# index: 4171
# Lable: 3
# index: 5223
# Lable: 7
# index: 945
# Lable: 0
# ___________________

# %% [markdown]
# # Validation of Task

# %%
# Checking the shape of first image in new training dataset
print(new_dataset[0][0][0].shape)
print("___________________")


# Checking the size of dataset
print("There are",len(new_dataset[0][1]),"labels in training dataset for",len(new_dataset[0][0]),"images in training dataset")
print("There are",len(new_dataset[1][1]),"labels in training dataset for",len(new_dataset[1][0]),"images in training dataset")
print("___________________\n\n")
# Excepted output
# There are 6000 labels in training dataset for 6000 images in training dataset
# There are 1000 labels in training dataset for 1000 images in training dataset




# Checking the number of images per class
print("There are", len(set(new_dataset[0][1])),"unique classes in training dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(new_dataset[0][1]))
print("There are", len(set(new_dataset[1][1])),"unique classes in validation dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(new_dataset[1][1]))
print("___________________\n\n")
# Expected output
# There are 10 unique classes in training dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({0: 600,
#          1: 600,
#          2: 600,
#          3: 600,
#          4: 600,
#          5: 600,
#          6: 600,
#          7: 600,
#          8: 600,
#          9: 600})
# There are 10 unique classes in validation dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({0: 100,
#          1: 100,
#          2: 100,
#          3: 100,
#          4: 100,
#          5: 100,
#          6: 100,
#          7: 100,
#          8: 100,
#          9: 100})


# Checking the correctness of indexing of image and its labels
print("Randomly printing 10 images with labels from training dataset")
display_random_images_with_labels(new_dataset[0])
print("___________________\n\n")
print("Randomly printing 10 images with labels from testing dataset")
display_random_images_with_labels(new_dataset[0])
print("___________________\n\n")
# Out:
# (28, 28)
# ___________________
# There are 6000 labels in training dataset for 6000 images in training dataset
# There are 1000 labels in training dataset for 1000 images in training dataset
# ___________________
#
#
# There are 10 unique classes in training dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({5: 600,
#          0: 600,
#          4: 600,
#          1: 600,
#          9: 600,
#          2: 600,
#          3: 600,
#          6: 600,
#          7: 600,
#          8: 600})
# There are 10 unique classes in validation dataset
# Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)
# Counter({7: 100,
#          2: 100,
#          1: 100,
#          0: 100,
#          4: 100,
#          9: 100,
#          5: 100,
#          6: 100,
#          3: 100,
#          8: 100})
# ___________________
#
#
# Randomly printing 10 images with labels from training dataset
# index: 2033
# Lable: 1
# index: 5193
# Lable: 7
# index: 4934
# Lable: 7
# index: 4938
# Lable: 7
# index: 3920
# Lable: 3
# index: 3059
# Lable: 2
# index: 2424
# Lable: 9
# index: 3108
# Lable: 2
# index: 5039
# Lable: 7
# index: 314
# Lable: 5
# ___________________
#
#
# Randomly printing 10 images with labels from testing dataset
# index: 2190
# Lable: 1
# index: 525
# Lable: 5
# index: 3594
# Lable: 2
# index: 4712
# Lable: 6
# index: 4887
# Lable: 7
# index: 4506
# Lable: 6
# index: 1698
# Lable: 4
# index: 4500
# Lable: 6
# index: 1213
# Lable: 4
# index: 3649
# Lable: 3
# ___________________
